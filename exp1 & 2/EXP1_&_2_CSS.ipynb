# %% [markdown]
# <a href="https://colab.research.google.com/github/mansidw/CSS_Lab/blob/main/EXP1_CSS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#exp1
print("Enter the Cryptography Method you want to implement :")
print("1. Substitution")
print("2. ROT 13")
print("3. Transpose")
print("4. Double Transposition")
print("5. Vernam Cipher")
print("6. End Program")
e=True
while e:
  print()
  print()
  print("Enter Choice :")
  n=int(input())
  if n==1:
    print("I) SUBSTITUTION METHOD")
    text1=input("Enter the text to be encrypted :")
    # text2=input("Enter the text to be decrypted :")
    shift=int(input("Enter the number of position shift :"))
    text2=''
    print("Encrypted Message-")
    for i in range(0,len(text1)):
      if ord(text1[i])+shift<=122:text2+=chr(ord(text1[i])+shift)
      else:text2+=chr(ord(text1[i])+shift-26)
    print(text2)
    print()
    print("Decrypted Message-")
    for i in range(0,len(text2)):
      if text2[i]=='"':print(" ",end="")
      elif ord(text2[i])-shift>=97:print(chr(ord(text2[i])-shift),end="")
      else:print(chr(ord(text2[i])-shift+26),end="")

  elif n==2:
    print("II) ROT 13 METHOD")
    text1=input("Enter the text to be encrypted :")
    text2=''
    # text2=input("Enter the text to be decrypted :")
    print("Encrypted Message-")
    for i in range(0,len(text1)):
      if ord(text1[i])+13<=122:text2+=chr(ord(text1[i])+13)
      else:text2+=chr(ord(text1[i])-13)
    print(text2)
    print()
    print("Decrypted Message-")
    for i in range(0,len(text2)):
      if text2[i]=='-':print(" ",end="")
      elif ord(text2[i])-13>=97:print(chr(ord(text2[i])-13),end="")
      else:print(chr(ord(text2[i])+13),end="")

  elif n==3:
    print("III) TRANSPOSITION METHOD")
    text1=input("Enter the text to be encrypted :")
    text2=''
    # text2=input("Enter the text to be decrypted :")
    print("Encrypted Message-")
    if len(text1)<2:print(text1)
    else:
      for i in range(0,2):
        j=2
        text2+=text1[i]
        while i+j<len(text1):
          text2+=text1[i+j]
          j+=2
    print(text2)
    print()
    print("Decrypted Message-")
    if len(text2)<2:print(text2)
    else:
      if len(text2)%2==0:a=int(len(text2)/2)
      else: a=int(len(text2)//2+1)
      for i in range(0,a):
        j=a
        print(text2[i],end="")
        while i+j<len(text2):
          print(text2[i+j],end="")
          j+=a

  elif n==4:
    print("IV) DOUBLE TRANSPOSITION METHOD")
    text1=input("Enter the text to be encrypted :")
    text2=''
    # text2=input("Enter the text to be decrypted :")
    str1=""
    str2=""
    print("Encrypted Message-")
    if len(text1)<2:print(text1)
    else:
      for i in range(0,2):
        j=2
        str1+=text1[i]
        while i+j<len(text1):
          str1+=text1[i+j]
          j+=2
      for i in range(0,2):
        j=2
        text2+=str1[i]
        while i+j<len(str1):
          text2+=str1[i+j]
          j+=2
    print(text2)
    print()
    print("Decrypted Message-")
    if len(text2)<2:print(text2)
    else:
      if len(text2)%2==0:a=int(len(text2)/2)
      else: a=int(len(text2)//2+1)
      for i in range(0,a):
        j=a
        str2+=text2[i]
        while i+j<len(text2):
          str2+=text2[i+j]
          j+=a
      for i in range(0,a):
        j=a
        print(str2[i],end="")
        while i+j<len(str2):
          print(str2[i+j],end="")
          j+=a

  elif n==5:
    print("V) VERNAM CIPHER METHOD")
    text1=input("Enter the text to be encrypted :")
    text2=''
    # text2=input("Enter the text to be decrypted :")
    key=input("Enter the key text :")
    print("Encrypted Message-")
    for i in range(0,len(text1)):
      if ord(text1[i])+ord(key[i])-194>25:text2+=chr(ord(text1[i])+ord(key[i])-123)
      else:text2+=chr(ord(text1[i])+ord(key[i])-97)
    print(text2)
    print()
    print("Decrypted Message-")
    for i in range(0,len(text2)):
      if ord(text2[i])<ord(key[i]):print(chr(ord(text2[i])-ord(key[i])+123),end="")
      else:print(chr(ord(text2[i])-ord(key[i])+97),end="")

  else:
    e=False
#1 hello mansi jgnnq"ocpuk 2
#2 god bless you tbq-oyrff-lbh
#3 hey there mansi hyteemnie hr as 
#4 life's good l'oisof deg
#5 mansi mrpzq archi

#a rose is a rose is a rose
#may god bless you and bless me
#we are good and so are you  w r odads r oeaego n oaeyu
#as good as it gets  aoattg ie d gsos s
#wearegood wearenice siaiitwqh
# Out:
# Enter the Cryptography Method you want to implement :
# 1. Substitution
# 2. ROT 13
# 3. Transpose
# 4. Double Transposition
# 5. Vernam Cipher
# 6. End Program
#
#
# Enter Choice :
# 1
# I) SUBSTITUTION METHOD
# Enter the text to be encrypted :a rose is a rose is a rose
# Enter the number of position shift :2
# Encrypted Message-
# c"tqug"ku"c"tqug"ku"c"tqug
#
# Decrypted Message-
# a rose is a rose is a rose
#
# Enter Choice :
# 2
# II) ROT 13 METHOD
# Enter the text to be encrypted :may god bless you and bless me
# Encrypted Message-
# znl-tbq-oyrff-lbh-naq-oyrff-zr
#
# Decrypted Message-
# may god bless you and bless me
#
# Enter Choice :
# 3
# III) TRANSPOSITION METHOD
# Enter the text to be encrypted :we are good and so are you
# Encrypted Message-
# w r odads r oeaego n oaeyu
#
# Decrypted Message-
# we are good and so are you
#
# Enter Choice :
# 4
# IV) DOUBLE TRANSPOSITION METHOD
# Enter the text to be encrypted :as good as it gets
# Encrypted Message-
# aoattg ie d gsos s
# ...

# %%
#14698154927
#2796203
#636784
#543564

# %%
#diffie hellman
g = int(input("Enter the first prime number : "))
n = int(input("Enter the second prime number : "))
x = int(input("Enter the secret X for Alice : "))
y = int(input("Enter the secret Y for Bob : "))
public1 = (n**x)%g
public2 = (n**y)%g
print("The generated key of Alice is : ",public1)
print("The generated key of Bob is : ",public2)
secret1 = (public1**y)%g
secret2 = (public2**x)%g
print("Their shared secret is : ",secret1)
print("Their shared secret is : ",secret2)
# Out:
# Enter the first prime number : 14698154927
# Enter the second prime number : 2796203
# Enter the secret X for Alice : 636784
# Enter the secret Y for Bob : 543564
# The generated key of Alice is :  988944465
# The generated key of Bob is :  12426855390
# Their shared secret is :  5081268055
# Their shared secret is :  5081268055
